# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import os

# %% [markdown]
# ## Read the dataset from the file

# %%
df_kc_house_data=pd.read_csv("kc_house_data.csv")

# %% [markdown]
# # print the dataset info :

# %%
df_kc_house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# # There are variables that are intuitively useless, delete them

# %%
cols = list(df_kc_house_data.columns)
cols.remove('date')
cols.remove('id')
cols.remove('yr_built') 
cols.remove('yr_renovated') 
cols.remove('zipcode')

# %%
cols
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# # Calculate the mean and the median for each numerical variable

# %%
df2 = df_kc_house_data[cols].mean()
print(df2)
# Out:
# price            540088.141767
# bedrooms              3.370842
# bathrooms             2.114757
# sqft_living        2079.899736
# sqft_lot          15106.967566
# floors                1.494309
# waterfront            0.007542
# view                  0.234303
# condition             3.409430
# grade                 7.656873
# sqft_above         1788.390691
# sqft_basement       291.509045
# lat                  47.560053
# long               -122.213896
# sqft_living15      1986.552492
# sqft_lot15        12768.455652
# dtype: float64

# %%
df3=df_kc_house_data[cols]
print(df3)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement      lat  \
# ...

# %%
df_kc_house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# # Detect the outliers and deal with them

# %% [markdown]
# # listwise deletion

# %%
df_kc_house_data.dropna(inplace=True)

# %%
#deleting a column
df_kc_house_data=df_kc_house_data.drop(['sqft_living'], cols=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12876/2607851041.py in <module>
#       1 #deleting a column
# ----> 2 df_kc_house_data=df_kc_house_data.drop(['sqft_living'], cols=3)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: drop() got an unexpected keyword argument 'cols'

# %%
df_kc_house_data.isna()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# # Using a feature selection technique of your choice

# %%
col = list(df_kc_house_data.columns)
col.remove('price')
col.remove('date')
col.remove('id')
col.remove('yr_built') 
col.remove('yr_renovated') 
col.remove('zipcode')
col
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df_housing_numerical=df_kc_house_data[col]
df_housing_numerical.corr()
# Out:
#                bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# bedrooms       1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront    -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.477600   0.685342     0.876597  0.183512  0.523885
# sqft_basement  0.303093   0.283770     0.435043  0.015286 -0.245705
# lat           -0.008931   0.024573     0.052529 -0.085683  0.049614
# long           0.129473   0.223042     0.240223  0.229521  0.125419
# ...

# %%
sns.heatmap(df_housing_numerical.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Do linear regression on the independent variable price and the selected features from the previous step

# %%
from sklearn.linear_model import LinearRegression
df_kc_house_data.dropna(inplace=True)

# %%
model = LinearRegression()
x=df_kc_house_data.iloc[:,2:4].values.reshape(-1,1)
y=df_kc_house_data.iloc[:,2:4].values.reshape(-1,1)
model.fit(x,y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(x)
plt.scatter(x,y)
plt.plot(x,Y_pred,color='purple')
plt.show()

r_squared = model.score(x,y)
print( "r² is : ",r_squared)

b=model.intercept_
a=model.coef_

print("y = {} * x +{}".format(a[0][0],b[0]))
y=model.predict()
# Out:
# r² is :  1.0
# y = 1.0000000000000062 * x +-1.6880221664905548e-09
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12876/857164753.py in <module>
#      11
#      12 print("y = {} * x +{}".format(a[0][0],b[0]))
# ---> 13 y=model.predict()
#
# TypeError: predict() missing 1 required positional argument: 'X'
